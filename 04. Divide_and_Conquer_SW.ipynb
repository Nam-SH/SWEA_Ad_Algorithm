# %% [markdown]
# # 5204. 병합 정렬
#
# <br>
#
# ![image](https://user-images.githubusercontent.com/50367487/65002416-a74bda80-d92e-11e9-9ec4-3d85dce93fdb.png)

# %%
import sys; sys.stdin = open('data/(5204)input.txt', 'r')

def merge_sort(arr):
    global cnt1

    if len(arr) <= 1: return arr

    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]
    left1 = merge_sort(left)
    right1 = merge_sort(right)

    return merge(left1, right1)

def merge(left, right):
    global cnt

    i = j = 0
    sorted_lst = []

    if left[-1] > right[-1]: cnt += 1

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            sorted_lst.append(left[i])
            i += 1
        else:
            sorted_lst.append(right[j])
            j += 1
    while i < len(left):
        sorted_lst.append(left[i])
        i += 1

    while j < len(right):
        sorted_lst.append(right[j])
        j += 1

    return sorted_lst

for tc in range(int(input())):
    N = int(input())
    arr = list(map(int, input().split()))
    cnt = cnt1 = 0
    print('#{} {} {}'.format(tc + 1, merge_sort(arr)[len(arr)//2], cnt))

# %% [markdown]
# # 5205. 퀵 정렬
#
# <br>
#
# ![image](https://user-images.githubusercontent.com/50367487/65002420-ad41bb80-d92e-11e9-82ad-4e42928a9f22.png)

# %%
import sys; sys.stdin = open('data/(5205)input.txt', 'r')

def quicksort(lo, hi):
    if lo >= hi: return
    i = lo - 1
    for j in range(lo, hi):
        if arr[hi] >= arr[j]:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    i += 1
    arr[hi], arr[i] = arr[i], arr[hi]

    quicksort(lo, i - 1)
    quicksort(i + 1, hi)

for tc in range(int(input())):
    N = int(input())
    arr = list(map(int, input().split()))

    quicksort(0, len(arr)-1)

    print('#{} {}'.format(tc + 1, arr[N//2]))

# %%
import sys; sys.stdin = open('data/(5205)input.txt', 'r')

def quick_sort1(arr):

    if len(arr) <= 1: return arr

    pivot = arr[0]
    greater = [element for element in arr[1:] if element > pivot]
    lesser = [element for element in arr[1:] if element <= pivot]

    return quick_sort1(lesser) + [pivot] + quick_sort1(greater)

for tc in range(int(input())):
    N = int(input())
    arr = list(map(int, input().split()))
    print('#{} {}'.format(tc + 1, quick_sort1(arr)[len(arr)//2]))

# %%
import sys; sys.stdin = open('data/(5205)input.txt', 'r')

def quick_sort2(x):
    if len(x) <= 1: return x

    pivot = x[len(x)//2]
    left,right,equal =[],[],[]
    
    for a in x:
        if a < pivot: left.append(a)
        elif a > pivot: right.append(a)
        else: equal.append(a)
    
    return quick_sort2(left) + equal + quick_sort2(right)


for tc in range(int(input())):
    N = int(input())
    arr = list(map(int, input().split()))
    print('#{} {}'.format(tc + 1, quick_sort2(arr)[len(arr)//2]))

# %%
import sys; sys.stdin = open('data/(5205)input.txt', 'r')

def quick_sort(arr):
    
    def sort(low, high):
        if high <= low: return

        mid = partition(low, high)
        sort(low, mid - 1)
        sort(mid, high)

    def partition(low, high):
        pivot = arr[(low + high) // 2]
        while low <= high:
            while arr[low] < pivot:
                low += 1
            while arr[high] > pivot:
                high -= 1
            if low <= high:
                arr[low], arr[high] = arr[high], arr[low]
                low, high = low + 1, high - 1
        return low

    return sort(0, len(arr) - 1)


for tc in range(int(input())):
    N = int(input())
    arr = list(map(int, input().split()))
    quick_sort(arr)
    print('#{} {}'.format(tc + 1, arr[N//2]))

# %% [markdown]
# # 5207. 이진 탐색
#
# <br>
#
# ![image](https://user-images.githubusercontent.com/50367487/65002427-b599f680-d92e-11e9-806c-6f4c81d21a1a.png)

# %%
import sys; sys.stdin = open('data/(5207)input.txt', 'r')

def binary_search_recursion(target, start, end, data):
    global cnt

    if start > end: return

    mid = (start + end) // 2

    if data[mid] >= target:
        if data[mid] == target:
            cnt += 1
            return
        end = mid - 1

    else: start = mid + 1

    binary_search_recursion(target, start, end, data)

for tc in range(int(input())):
    N, M = map(int, input().split())
    arr1 = sorted(list(map(int, input().split())))
    arr2 = list(map(int, input().split()))
    cnt = 0
    for target in arr2:
        binary_search_recursion(target, 0, len(arr1) - 1, arr1)

    print('#{} {}'.format(tc + 1, cnt))
